# %%
import openai

# Set up the OpenAI API client
openai.api_key = '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'  # Replace with your actual API key

# Define the input prompt
prompt = "OpenAI is revolutionizing artificial intelligence."

# Generate the embeddings
response = openai.Completion.create(
    engine='text-davinci-003',
    prompt=prompt,
    max_tokens=100,
    logprobs=0
)

print(response)
# Out:
# {
#   "id": "cmpl-7cpOCRxRAhhiDnFxA66RQDcoKzYV3",
#   "object": "text_completion",
#   "created": 1689488360,
#   "model": "text-davinci-003",
#   "choices": [
#     {
#       "text": " Founded by Elon Musk, Sam Altman, and Greg Brockman, OpenAI is a non-profit research organization dedicated to advancing artificial intelligence in a beneficial way. OpenAI\u2019s mission is to develop and promote artificial general intelligence for the benefits of humanity. Their research focuses on artificial general intelligence  (AGI) which refers to machines that are as intelligent as humans across a range of tasks. OpenAI strives to develop technologies with high potential for future advancement and to share those technologies with",
#       "index": 0,
#       "logprobs": {
#         "tokens": [
#           " Found",
#           "ed",
#           " by",
#           " Elon",
#           " Musk",
#           ",",
#           " Sam",
#           " Alt",
#           "man",
#           ",",
# ...

# %%
# Extract the embeddings
embeddings = response['choices'][0]['logprobs']['token_logprobs']

# Print the embeddings
print(embeddings)
# Out:
# [-0.5613826, -0.09196539, -0.65509194, -1.0451679, -0.003953483, -0.00077964604, -0.41648734, -1.4620888, -2.9538546, -0.17846605, -0.014053555, -0.0021643366, -2.1552734, -0.82153124, -5.6453357, -0.092039295, -2.5932696, -2.7197587, -3.0353855e-05, -1.7229599, -1.2020357, -1.9825808, -0.45528987, -0.20896755, -0.18073823, -8.684499, -0.21035412, -0.08809045, -3.8808444, -0.16824657, -2.334529, -1.4782765, -1.4950664, -0.04607557, -0.92715526, -0.009598235, -2.4382973, -0.017419955, -0.753986, -8.046862, -1.2546426, -1.9903253, -0.898448, -1.1578732, -0.25951397, -3.756582, -0.25251412, -0.34899753, -1.6781579, -5.647938, -2.1450295, -0.1546254, -1.517124, -0.18182214, -11.246722, -1.8531669, -0.35677856, -1.5466408, -6.4425154, -0.5086138, -0.09009571, -1.5655923, -0.22822435, -2.218245, -3.3961556, -0.010809479, -0.26160002, -5.307691, -2.7728449e-05, -0.00013872207, -0.94877726, -0.018372519, -0.011169014, -1.3363321, -0.11200229, -0.0011586235, -0.10583548, -0.074786864, -0.0173
# ...
